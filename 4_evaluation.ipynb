# %% [markdown]
# # 4. Evaluation
# ## German Weather Big Data ML Pipeline
#
# **This notebook covers:**
# - Evaluation metrics: ROC-AUC, Accuracy, Precision, Recall, F1, PR-AUC (6+ metrics)
# - Confusion matrices and ROC/PR curves visualization
# - Bootstrap confidence intervals (1000 iterations, 95% CI)
# - Stability analysis (perturbation test - remove 5% data, retrain)
# - Feature importance visualization
# - Learning curves (accuracy vs training size)
# - Strong/weak scaling experiments
# - Cost-benefit threshold optimization
# - Export all results as CSV for Tableau dashboards
#
# *Full implementation: see main Google Colab notebook*

# %%
# Code extracted from main Colab notebook - Section 4
# See Google Colab link in README.md
