# %% [markdown]
# # 1. Data Ingestion
# ## German Weather Big Data ML Pipeline
#
# **This notebook covers:**
# - SparkSession configuration with optimized settings
# - Download DWD CDC hourly weather data (8 parameters, 500+ stations)
# - Schema validation and data quality checks
# - Parquet conversion with snappy compression
# - Partitioning by year/month for efficient queries
# - Broadcast join for station metadata
# - Spark UI screenshots for optimization evidence
#
# **Data Source:** https://opendata.dwd.de/climate_environment/CDC/
#
# *Full implementation: see main Google Colab notebook*

# %%
# Code extracted from main Colab notebook - Section 1
# See Google Colab link in README.md
